# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import yfinance as yf

# %%
db1 = pd.read_excel("tbl_email_1.xlsx").head(10)
db2 = pd.read_excel("tbl_communication_stream_1.xlsx").head(50)
db3 = pd.read_excel("tbl_sentence_1.xlsx").head(50)
all_db = pd.concat([db1,db2], axis=1)
plt.figure(figsize=(10,7))
NG = nx.from_pandas_edgelist(db2, 'comm_stream_id', 'email_id')
nx.draw(NG, with_labels = True, node_color='red')

# %%
NG2 = nx.from_pandas_edgelist(db3.head(50), 'from(email index)', 'email_id')
nx.draw(NG2, with_labels = True, node_color='red')

# %%
NG3 = nx.from_pandas_edgelist(db3.head(150), 'to(email index)', 'email_id')
nx.draw(NG3, with_labels = True, node_color='red')
