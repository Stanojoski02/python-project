# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import yfinance as yf

# %%
var1 = yf.Ticker('AAPL')

# %%
apple = var1.institutional_holders

# %%
apple['comp'] = var1.ticker
apple
# Out:
#                           Holder      Shares Date Reported   % Out  \
# 0     Vanguard Group, Inc. (The)  1272378901    2022-09-29  0.0800
# 1                 Blackrock Inc.  1020245185    2022-09-29  0.0641
# 2        Berkshire Hathaway, Inc   894802319    2022-09-29  0.0562
# 3       State Street Corporation   591543874    2022-09-29  0.0372
# 4                       FMR, LLC   350900116    2022-09-29  0.0221
# 5  Geode Capital Management, LLC   279758518    2022-09-29  0.0176
# 6  Price (T.Rowe) Associates Inc   224863541    2022-09-29  0.0141
# 7                 Morgan Stanley   182728771    2022-09-29  0.0115
# 8     Northern Trust Corporation   176084862    2022-09-29  0.0111
# 9    Bank of America Corporation   142260591    2022-09-29  0.0089
#
#           Value  comp
# 0  192218289893  AAPL
# 1  154128447570  AAPL
# 2  135177792885  AAPL
# 3   89364537377  AAPL
# 4   53010483094  AAPL
# 5   42263121363  AAPL
# 6   33970136785  AAPL
# 7   27604836773  AAPL
# ...

# %%
var2 = yf.Ticker('MSFT')
msft = var2.institutional_holders

# %%
msft['comp'] = var2.ticker

# %%
tog_ = pd.concat([apple,msft])
tog_
# Out:
#                             Holder      Shares Date Reported   % Out  \
# 0       Vanguard Group, Inc. (The)  1272378901    2022-09-29  0.0800
# 1                   Blackrock Inc.  1020245185    2022-09-29  0.0641
# 2          Berkshire Hathaway, Inc   894802319    2022-09-29  0.0562
# 3         State Street Corporation   591543874    2022-09-29  0.0372
# 4                         FMR, LLC   350900116    2022-09-29  0.0221
# 5    Geode Capital Management, LLC   279758518    2022-09-29  0.0176
# 6    Price (T.Rowe) Associates Inc   224863541    2022-09-29  0.0141
# 7                   Morgan Stanley   182728771    2022-09-29  0.0115
# 8       Northern Trust Corporation   176084862    2022-09-29  0.0111
# 9      Bank of America Corporation   142260591    2022-09-29  0.0089
# 0       Vanguard Group, Inc. (The)   634238715    2022-09-29  0.0851
# 1                   Blackrock Inc.   518843676    2022-09-29  0.0696
# 2         State Street Corporation   295509547    2022-09-29  0.0396
# ...

# %%
G = nx.from_pandas_edgelist(tog_, 'Holder', 'comp')
G

# %%
G.nodes()
# Out:
# NodeView(('Vanguard Group, Inc. (The)', 'AAPL', 'Blackrock Inc.', 'Berkshire Hathaway, Inc', 'State Street Corporation', 'FMR, LLC', 'Geode Capital Management, LLC', 'Price (T.Rowe) Associates Inc', 'Morgan Stanley', 'Northern Trust Corporation', 'Bank of America Corporation', 'MSFT', 'Capital World Investors', 'JP Morgan Chase & Company', 'Capital International Investors'))

# %%
nx.draw(G, with_labels = True)

# %%
db1 = pd.read_excel("tbl_email_1.xlsx").head(10)
db2 = pd.read_excel("tbl_communication_stream_1.xlsx").head(10)
all_db = pd.concat([db1,db2])
plt.figure(figsize=(13,10))
NG = nx.from_pandas_edgelist(all_db, 'comm_stream_id', 'email_id')
nx.draw(NG, with_labels = True)
