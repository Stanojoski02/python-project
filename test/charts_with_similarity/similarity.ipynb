# %%
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_excel('tbl_sentence_0.xlsx') # reads the excel file
sns.relplot(data=df[['verb','jaccard_similarity']],x="verb", y="jaccard_similarity", kind="line")
sns.relplot(data=df[['adjective','jaccard_similarity']],x="adjective", y="jaccard_similarity", kind="line")

# %%
sns.relplot(data=df[['propn','jaccard_similarity']],x="propn", y="jaccard_similarity", kind="line")
sns.relplot(data=df[['noun','jaccard_similarity']],x="noun", y="jaccard_similarity", kind="line")

# %%
sns.relplot(data=df[['verb','cosine_similarity']],x="verb", y="cosine_similarity", kind="line")

# %%
sns.relplot(data=df[['propn','cosine_similarity']],x="propn", y="cosine_similarity", kind="line")
sns.relplot(data=df[['noun','cosine_similarity']],x="noun", y="cosine_similarity", kind="line")

# %%
sns.relplot(data=df[['propn','cosine_similarity']],x="propn", y="cosine_similarity", color='red')
sns.relplot(data=df[['noun','cosine_similarity']],x="noun", y="cosine_similarity", color='red')

# %%
sns.relplot(data=df[['verb','cosine_similarity']],x="verb", y="cosine_similarity", color='red')
sns.relplot(data=df[['adjective','cosine_similarity']],x="adjective", y="cosine_similarity", color='red')

# %%
sns.relplot(data=df[['propn','jaccard_similarity']],x="propn", y="jaccard_similarity", color='red')
sns.relplot(data=df[['noun','jaccard_similarity']],x="noun", y="jaccard_similarity", color='red')

# %%
sns.relplot(data=df[['verb','jaccard_similarity']],x="verb", y="jaccard_similarity", color='red')
sns.relplot(data=df[['adjective','jaccard_similarity']],x="adjective", y="jaccard_similarity", color='red')

# %%
sns.relplot(data=df[['verb','levenshtein_distance']],x="verb", y="levenshtein_distance", color='purple')
sns.relplot(data=df[['adjective','levenshtein_distance']],x="adjective", y="levenshtein_distance", color='purple')

# %%
sns.relplot(data=df[['propn','levenshtein_distance']],x="propn", y="levenshtein_distance", color='red')
sns.relplot(data=df[['noun','levenshtein_distance']],x="noun", y="levenshtein_distance", color='red')

# %%
df
sns.relplot(data=df[['propn','euclidean_distance']],x="propn", y="euclidean_distance", color='blue')
sns.relplot(data=df[['noun','euclidean_distance']],x="noun", y="euclidean_distance", color='blue')

# %%
sns.relplot(data=df[['verb','euclidean_distance']],x="verb", y="euclidean_distance", color='green')
sns.relplot(data=df[['adjective','euclidean_distance']],x="adjective", y="euclidean_distance", color='green')
